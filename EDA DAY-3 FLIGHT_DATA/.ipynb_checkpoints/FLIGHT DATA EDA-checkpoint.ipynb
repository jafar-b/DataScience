# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
trdf=pd.read_excel('Data_Train.xlsx')
tsdf=pd.read_excel('Test_Set.xlsx')

# %%
df=pd.concat([trdf,tsdf])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.2+ MB

# %%
#FEATURE ENGINEERING
df['day']=df['Date_of_Journey'].str.split('/').str[0]

# %%
df['month']=df['Date_of_Journey'].str.split('/').str[1]
df['year']=df['Date_of_Journey'].str.split('/').str[2]

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price day  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0  24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0   1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0   9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0  12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0  01
#
#   month  year
# 0    03  2019
# 1    05  2019
# ...

# %%
df=df.drop('Date_of_Journey',axis=1)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info    Price day month  year
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897.0  24    03  2019
# 1         13:15   7h 25m     2 stops         No info   7662.0   1    05  2019
# 2  04:25 10 Jun      19h     2 stops         No info  13882.0   9    06  2019
# 3         23:30   5h 25m      1 stop         No info   6218.0  12    05  2019
# 4         21:35   4h 45m      1 stop         No info  13302.0  01    03  2019

# %%
df['month']=df['month'].astype(int)
df['day']=df['day'].astype(int)
df['year']=df['year'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Arrival_Time     13354 non-null  object
#  6   Duration         13354 non-null  object
#  7   Total_Stops      13353 non-null  object
#  8   Additional_Info  13354 non-null  object
#  9   Price            10683 non-null  float64
#  10  day              13354 non-null  int32
#  11  month            13354 non-null  int32
#  12  year             13354 non-null  int32
# dtypes: float64(1), int32(3), object(9)
# memory usage: 1.3+ MB

# %%
df['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
df['Source'].unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
df['Dep_Time'].unique()
# Out:
# array(['22:20', '05:50', '09:25', '18:05', '16:50', '09:00', '18:55',
#        '08:00', '08:55', '11:25', '09:45', '20:20', '11:40', '21:10',
#        '17:15', '16:40', '08:45', '14:00', '20:15', '16:00', '14:10',
#        '22:00', '04:00', '21:25', '21:50', '07:00', '07:05', '09:50',
#        '14:35', '10:35', '15:05', '14:15', '06:45', '20:55', '11:10',
#        '05:45', '19:00', '23:05', '11:00', '09:35', '21:15', '23:55',
#        '19:45', '08:50', '15:40', '06:05', '15:00', '13:55', '05:55',
#        '13:20', '05:05', '06:25', '17:30', '08:20', '19:55', '06:30',
#        '14:05', '02:00', '09:40', '08:25', '20:25', '13:15', '02:15',
#        '16:55', '20:45', '05:15', '19:50', '20:00', '06:10', '19:30',
#        '04:45', '12:55', '18:15', '17:20', '15:25', '23:00', '12:00',
#        '14:45', '11:50', '11:30', '14:40', '19:10', '06:00', '23:30',
#        '07:35', '13:05', '12:30', '15:10', '12:50', '18:25', '16:30',
# ...

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info    Price  day  month  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897.0   24      3
# 1         13:15   7h 25m     2 stops         No info   7662.0    1      5
# 2  04:25 10 Jun      19h     2 stops         No info  13882.0    9      6
# 3         23:30   5h 25m      1 stop         No info   6218.0   12      5
# 4         21:35   4h 45m      1 stop         No info  13302.0    1      3
#
#    year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
df['Arrival_Time']=df['Arrival_Time'].str.split(' ').str[0]

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  day  month  year
# 0        01:10   2h 50m    non-stop         No info   3897.0   24      3  2019
# 1        13:15   7h 25m     2 stops         No info   7662.0    1      5  2019
# 2        04:25      19h     2 stops         No info  13882.0    9      6  2019
# 3        23:30   5h 25m      1 stop         No info   6218.0   12      5  2019
# 4        21:35   4h 45m      1 stop         No info  13302.0    1      3  2019

# %%
df['arrivalhr']=df['Arrival_Time'].str.split(':').str[0].astype(int)
df['arrivalmin']=df['Arrival_Time'].str.split(':').str[1].astype(int)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  day  month  \
# 0        01:10   2h 50m    non-stop         No info   3897.0   24      3
# 1        13:15   7h 25m     2 stops         No info   7662.0    1      5
# 2        04:25      19h     2 stops         No info  13882.0    9      6
# 3        23:30   5h 25m      1 stop         No info   6218.0   12      5
# 4        21:35   4h 45m      1 stop         No info  13302.0    1      3
#
#    year  arrivalhr  arrivalmin
# 0  2019          1          10
# 1  2019         13          15
# ...

# %%
df['dephr']=df['Dep_Time'].str.split(':').str[0].astype(int)
df['depmin']=df['Dep_Time'].str.split(':').str[1].astype(int)

# %%
df.head(1)
# Out:
#   Airline    Source Destination      Route Dep_Time Arrival_Time Duration  \
# 0  IndiGo  Banglore   New Delhi  BLR → DEL    22:20        01:10   2h 50m
#
#   Total_Stops Additional_Info   Price  day  month  year  arrivalhr  \
# 0    non-stop         No info  3897.0   24      3  2019          1
#
#    arrivalmin  dephr  depmin
# 0          10     22      20

# %%
df.drop(['Arrival_Time','Dep_Time'],axis=1,inplace=True)

# %%
df.reset_index(drop=True)
# Out:
#                  Airline    Source Destination                  Route  \
# 0                 IndiGo  Banglore   New Delhi              BLR → DEL
# 1              Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2            Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK
# 3                 IndiGo   Kolkata    Banglore        CCU → NAG → BLR
# 4                 IndiGo  Banglore   New Delhi        BLR → NAG → DEL
# ...                  ...       ...         ...                    ...
# 13349          Air India   Kolkata    Banglore        CCU → DEL → BLR
# 13350             IndiGo   Kolkata    Banglore              CCU → BLR
# 13351        Jet Airways     Delhi      Cochin        DEL → BOM → COK
# 13352          Air India     Delhi      Cochin        DEL → BOM → COK
# 13353  Multiple carriers     Delhi      Cochin        DEL → BOM → COK
#
#       Duration Total_Stops Additional_Info    Price  day  month  year  \
# ...

# %%
df.drop('Route',axis=1,inplace=True)

# %%
df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
df['Total_Stops']=df['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4,'NaN':1})

# %%
df.head(1)
# Out:
#   Airline    Source Destination Duration  Total_Stops Additional_Info   Price  \
# 0  IndiGo  Banglore   New Delhi   2h 50m          0.0         No info  3897.0
#
#    day  month  year  arrivalhr  arrivalmin  dephr  depmin
# 0   24      3  2019          1          10     22      20

# %%
df['Total_Stops'].fillna('1',inplace=True)

# %%
df['Total_Stops']=df['Total_Stops'].astype(int)

# %%
df['Total_Stops'].unique()
# Out:
# array([0, 2, 1, 3, 4])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Duration         13354 non-null  object
#  4   Total_Stops      13354 non-null  int32
#  5   Additional_Info  13354 non-null  object
#  6   Price            10683 non-null  float64
#  7   day              13354 non-null  int32
#  8   month            13354 non-null  int32
#  9   year             13354 non-null  int32
#  10  arrivalhr        13354 non-null  int32
#  11  arrivalmin       13354 non-null  int32
#  12  dephr            13354 non-null  int32
#  13  depmin           13354 non-null  int32
# dtypes: float64(1), int32(8), object(5)
# memory usage: 1.1+ MB

# %%
hour=df['Duration'].str.split(" ").str[0].str.replace("h","").str.replace("5m",'5')

# %%
hour.astype(int)
# Out:
# 0        2
# 1        7
# 2       19
# 3        5
# 4        4
#         ..
# 2666    23
# 2667     2
# 2668     6
# 2669    15
# 2670    14
# Name: Duration, Length: 13354, dtype: int32

# %%
minu=df['Duration'].str.split(" ").str[1].str.replace('m','')

# %%
minu.unique()
# Out:
# array(['50', '25', nan, '45', '30', '5', '15', '35', '10', '20', '55',
#        '40'], dtype=object)

# %%
hour=hour.astype(int)

# %%
minu.fillna(30,inplace=True)

# %%
hour=(hour*60)

# %%
minu=minu.astype(int)

# %%
df['Duration']=hour+minu

# %%
df['Duration'].unique()
# Out:
# array([ 170,  445, 1170,  325,  285,  145,  930, 1265, 1530,  470,  795,
#         155,  135,  730, 1595,  270, 1355, 1410, 1235,  310,  920,  175,
#         800,  910,  345,  355,  805, 1350,  330,  625,  315,  150,  375,
#         715,  665,  510, 1325,  165,  750,  965, 1195,  195, 1520,  210,
#         975,  905,  390, 1505,  745, 1640,  615,  630,   90,   85, 1590,
#         440,  810, 1145,  890,  160, 1330,  575, 1280, 1125,  740, 1110,
#         555, 1050,  995,  735,  450, 1470,  535,  430,  870, 1820,  765,
#         610,  925,  845, 1215, 1390, 1090,  990,  140, 1015,  190, 1430,
#        1300, 1275,  650,  495,  515,  710, 1655,  505, 1255,  290,  490,
#        1465, 1415, 1545, 1570, 1730, 1515,  560,  550,  185,  690,  570,
#        1055,  305, 1550, 1230, 1105, 1450,  295, 1535,  380, 1120, 1165,
#        1760,  545,  645,  700, 1375, 2245, 1540,  835,  520,  755, 1455,
#          80,  675,  875,  775,  460,  705, 1495, 1025, 1795, 1335,  880,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Duration         13354 non-null  int32
#  4   Total_Stops      13354 non-null  int32
#  5   Additional_Info  13354 non-null  object
#  6   Price            10683 non-null  float64
#  7   day              13354 non-null  int32
#  8   month            13354 non-null  int32
#  9   year             13354 non-null  int32
#  10  arrivalhr        13354 non-null  int32
#  11  arrivalmin       13354 non-null  int32
#  12  dephr            13354 non-null  int32
#  13  depmin           13354 non-null  int32
# dtypes: float64(1), int32(9), object(4)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Duration              0
# Total_Stops           0
# Additional_Info       0
# Price              2671
# day                   0
# month                 0
# year                  0
# arrivalhr             0
# arrivalmin            0
# dephr                 0
# depmin                0
# dtype: int64

# %%
df['Price'].mode()
# Out:
# 0    10262.0
# Name: Price, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['Airline']=lb.fit_transform(df['Airline'])
df['Source']=lb.fit_transform(df['Source'])
df['Destination']=lb.fit_transform(df['Destination'])
df['Additional_Info']=lb.fit_transform(df['Additional_Info'])

# %%
df.head()
# Out:
#    Airline  Source  Destination  Duration  Total_Stops  Additional_Info  \
# 0        3       0            5       170            0                8
# 1        1       3            0       445            2                8
# 2        4       2            1      1170            2                8
# 3        3       3            0       325            1                8
# 4        3       0            5       285            1                8
#
#      Price  day  month  year  arrivalhr  arrivalmin  dephr  depmin
# 0   3897.0   24      3  2019          1          10     22      20
# 1   7662.0    1      5  2019         13          15      5      50
# 2  13882.0    9      6  2019          4          25      9      25
# 3   6218.0   12      5  2019         23          30     18       5
# 4  13302.0    1      3  2019         21          35     16      50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  int32
#  1   Source           13354 non-null  int32
#  2   Destination      13354 non-null  int32
#  3   Duration         13354 non-null  int32
#  4   Total_Stops      13354 non-null  int32
#  5   Additional_Info  13354 non-null  int32
#  6   Price            10683 non-null  float64
#  7   day              13354 non-null  int32
#  8   month            13354 non-null  int32
#  9   year             13354 non-null  int32
#  10  arrivalhr        13354 non-null  int32
#  11  arrivalmin       13354 non-null  int32
#  12  dephr            13354 non-null  int32
#  13  depmin           13354 non-null  int32
# dtypes: float64(1), int32(13)
# memory usage: 886.8 KB

# %% [raw]
# # 1) Now do get_dummies on all of the categorical features--[Airline,Source,Destination,Additional_Info]
# 2) combine all dataframes of categorical features and df.
# 3)split data into test-train
# 4)pass through a machine learning algorithm.
