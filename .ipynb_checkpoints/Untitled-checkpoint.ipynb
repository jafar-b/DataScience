# %%
import numpy as np
import pandas as pd

# %%
dict={"name":["jafar","nabil","shahid"],
      "age":[19,19,19],
      "city":["ratnagiri","lanja","nivsar"]
     }

# %%
df=pd.DataFrame(dict)

# %%
df.to_csv("friends.csv")

# %%
df.to_csv("friends.csv",False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 df.to_csv("friends.csv",False)
#
# File C:\Python39\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
#    3553     line_terminator=line_terminator,
#    3554     sep=sep,
#    3555     encoding=encoding,
#    3556     errors=errors,
# ...

# %%
df.to_csv("friends.csv",index=False)

# %%
df.to_csv("friends.csv",index=True)

# %%
df.to_csv("friends.csv")

# %%
df.to_csv("friends.csv")

# %%
df.describe()

# %%
df.head()

# %%
df.head(2)

# %%
harry=pd.read_csv("friends.csv")

# %%
harry.describe()

# %%
harry['speed']

# %%
harry['name']

# %%
harry['name'][0]='hello'

# %%
harry.head()

# %%
harry['age'][0]=17

# %%
head()

# %%
harry.head()

# %%
harry.tail()

# %%
harry.name="namenmae"

# %%
harry.head()

# %%
ser=pd.Series(np.random.randint(34))

# %%
harry.head()

# %%
harry.head()

# %%
harry['age'][0]=17

# %%
harry.name="namenmae"

# %%
df.describe()

# %%
harry=df.DataFrame("Friends.csv")

# %%
harry=pd.DataFrame("Friends.csv")

# %%
harry=pd.read_csv("friends.csv")

# %%
harry=pd.read_csv("friends.csv")

# %%
df=pd.DataFrame(dict)

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("friends.csv")

# %%
dict={"name":["jafar","nabil","shahid"],"age":[17,18,19]}
df=pd.DataFrame(dict)

# %%
df.head()

# %%
df.describe()

# %%
newdf=pd.DataFrame(np.random.rand(334,5),index=np.arange(334))

# %%
newdf.head()

# %%
newdf

# %%
type(newdf)

# %%
newdf.describe()

# %%
newdf.to_numpy

# %%
type(newdf)

# %%
newdf.head()

# %%
dtype(newdf)

# %%
newdf.dtype()

# %%
newdf

# %%
newdf[0][0]="jafar"

# %%
newdf

# %%
newdf.sort_index(axis=0)

# %%
newdf.sort_index(axis=1)

# %%
newdf

# %%
type(newdf)

# %%
type(newdf[0])

# %%
newdf.tail()

# %%
select

# %%
newdf.columns=list("abcde")

# %%
newdf

# %%
newdf.rows=list("abcde")

# %%
newdf.rows=list("01234")

# %%
newdf

# %%
newdf.rows=list("qwerty")

# %%
newdf

# %%
newdf[0]="hello"

# %%
newdf

# %%
newdf.loc[0,a]="hello"

# %%
newdf[0,"a"]="hello"

# %%
newdf

# %%
newdf

# %%
newdf

# %%
newdf

# %%
df=pd.read_csv("friends.csv")

# %%
import numpy as np
import pandas as pd
df=pd.read_csv("friends.csv")
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Input In [6], in <cell line: 3>()
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 df=pd.read_csv("friends.csv")
#
# File C:\Python39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
dict={"name":["jafar","nabil","shahid"],
      "age":[19,19,19],
      "city":["ratnagiri","lanja","nivsar"]
     }

# %%
df=DataFrame(dict)

# %%
df=pd.DataFrame(dict)

# %%
df

# %%
df.describe()

# %%
df

# %%
df.drop(0)

# %%
df.drop(0,axis=1)

# %%
df

# %%
df.head()

# %%
df.drop(0)

# %%
df

# %%
newdf=df.drop(0)

# %%
newdf

# %%
newwdf=newdf.drop(0,axis=1)

# %%
newwdf

# %%
newdf

# %%
newdf.append("name":"jafar","age":20,"city":"ratnagiri")

# %%
df.append(pd.Series(["jafar",25,"ratnagiri"]))

# %%
df.append(pd.Series(["jafar",25,"ratnagiri"],ignore_index=True))

# %%
df.append(pd.Series(["jafar",25,"ratnagiri"]),ignore_index)

# %%
df.append(pd.Series(["jafar",25,"ratnagiri"]),ignore_index=True)

# %%
newdf

# %%
newdf.loc[0:3]

# %%
newdf.loc[0:2]

# %%
newdf.loc[0:1]

# %%
newdf.loc[:]

# %%
newdf.loc[len(df)]=["jafar",20,"ratnagiri"]

# %%
newdf

# %%
newdf.memory_usage()

# %%
newdf.memory_usage(deep=True)

# %%
newdf.drop(0)

# %%
newdf

# %%
newdf=pd.DataFrame(np.random.rand(334,5))

# %%
newdf

# %%
newdf.drop(0,axis=1)
newdf

# %%
newdf.drop(0,axis=1)

# %%
newdf.loc([newdf[0]<0.3])

# %%
newdf.loc([newdf[]<0.3])

# %%
newdf.loc([newdf[1]<0.3])

# %%
newdf.columns=["abcd"]

# %%
newdf.columns=["abcde"]

# %%
newdf.columns=list("abcde")

# %%
newdf

# %%
newdf.loc[(newdf['a']<0.3)]

# %%
newdf.loc[(newdf['a']<0.38)]

# %%
newdf.loc[(newdf['c']>0.3)]

# %%
newdf.head(2)

# %%
newdf.iloc[0,4]

# %%
newdf.iloc(0,"a")

# %%
newdf.iloc[0,1]

# %%
newdf.loc[[0,1],["a","b"]]

# %%
newdf

# %%
newdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 newdf
#
# NameError: name 'newdf' is not defined

# %%
import numpy,pandas

# %%
dict={"name":["jafar","nabil","shahid"],
      "age":[19,19,19],
      "city":["ratnagiri","lanja","nivsar"]
     }

# %%
df=pandas.DataFrame(dict)

# %%
df
# Out:
#      name  age       city
# 0   jafar   19  ratnagiri
# 1   nabil   19      lanja
# 2  shahid   19     nivsar

# %%
newdf=numpy.random.rand(334,5)

# %%
newdf
# Out:
# array([[0.24997534, 0.94403266, 0.30447546, 0.34810111, 0.32688904],
#        [0.7470931 , 0.59149556, 0.07720656, 0.90963004, 0.24333248],
#        [0.27445158, 0.3653906 , 0.83203535, 0.96123111, 0.07517552],
#        ...,
#        [0.54961767, 0.7657006 , 0.86926865, 0.48354634, 0.0385717 ],
#        [0.90857291, 0.21257756, 0.10516802, 0.37323835, 0.35506864],
#        [0.04648906, 0.63872335, 0.85480654, 0.57725129, 0.23776313]])

# %%
newdf.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 newdf.describe()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'describe'

# %%
newdf2=pd.DataFrame(newdf)

# %%
newdf2
# Out:
#             0         1         2         3         4
# 0    0.249975  0.944033  0.304475  0.348101  0.326889
# 1    0.747093  0.591496  0.077207  0.909630  0.243332
# 2    0.274452  0.365391  0.832035  0.961231  0.075176
# 3    0.926896  0.285163  0.494153  0.965522  0.280765
# 4    0.039616  0.740022  0.198664  0.578210  0.017244
# ..        ...       ...       ...       ...       ...
# 329  0.687377  0.056478  0.245931  0.193304  0.504506
# 330  0.656210  0.328748  0.782255  0.848526  0.808856
# 331  0.549618  0.765701  0.869269  0.483546  0.038572
# 332  0.908573  0.212578  0.105168  0.373238  0.355069
# 333  0.046489  0.638723  0.854807  0.577251  0.237763
#
# [334 rows x 5 columns]

# %%
newdf2.head(3)
# Out:
#           0         1         2         3         4
# 0  0.249975  0.944033  0.304475  0.348101  0.326889
# 1  0.747093  0.591496  0.077207  0.909630  0.243332
# 2  0.274452  0.365391  0.832035  0.961231  0.075176

# %%
newdf.columns=list("abcde")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 newdf.columns=list("abcde")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
newdf2.columns=list("abcde")

# %%
newdf2
# Out:
#             a         b         c         d         e
# 0    0.249975  0.944033  0.304475  0.348101  0.326889
# 1    0.747093  0.591496  0.077207  0.909630  0.243332
# 2    0.274452  0.365391  0.832035  0.961231  0.075176
# 3    0.926896  0.285163  0.494153  0.965522  0.280765
# 4    0.039616  0.740022  0.198664  0.578210  0.017244
# ..        ...       ...       ...       ...       ...
# 329  0.687377  0.056478  0.245931  0.193304  0.504506
# 330  0.656210  0.328748  0.782255  0.848526  0.808856
# 331  0.549618  0.765701  0.869269  0.483546  0.038572
# 332  0.908573  0.212578  0.105168  0.373238  0.355069
# 333  0.046489  0.638723  0.854807  0.577251  0.237763
#
# [334 rows x 5 columns]

# %%
newdf2.loc[[0,1],['a','b']]
# Out:
#           a         b
# 0  0.249975  0.944033
# 1  0.747093  0.591496

# %%
newdf2.head(3)
# Out:
#           a         b         c         d         e
# 0  0.249975  0.944033  0.304475  0.348101  0.326889
# 1  0.747093  0.591496  0.077207  0.909630  0.243332
# 2  0.274452  0.365391  0.832035  0.961231  0.075176

# %%
newdf2.drop(0)
# Out:
#             a         b         c         d         e
# 1    0.747093  0.591496  0.077207  0.909630  0.243332
# 2    0.274452  0.365391  0.832035  0.961231  0.075176
# 3    0.926896  0.285163  0.494153  0.965522  0.280765
# 4    0.039616  0.740022  0.198664  0.578210  0.017244
# 5    0.788482  0.044743  0.762381  0.792836  0.433401
# ..        ...       ...       ...       ...       ...
# 329  0.687377  0.056478  0.245931  0.193304  0.504506
# 330  0.656210  0.328748  0.782255  0.848526  0.808856
# 331  0.549618  0.765701  0.869269  0.483546  0.038572
# 332  0.908573  0.212578  0.105168  0.373238  0.355069
# 333  0.046489  0.638723  0.854807  0.577251  0.237763
#
# [333 rows x 5 columns]

# %%
newdf
# Out:
# array([[0.24997534, 0.94403266, 0.30447546, 0.34810111, 0.32688904],
#        [0.7470931 , 0.59149556, 0.07720656, 0.90963004, 0.24333248],
#        [0.27445158, 0.3653906 , 0.83203535, 0.96123111, 0.07517552],
#        ...,
#        [0.54961767, 0.7657006 , 0.86926865, 0.48354634, 0.0385717 ],
#        [0.90857291, 0.21257756, 0.10516802, 0.37323835, 0.35506864],
#        [0.04648906, 0.63872335, 0.85480654, 0.57725129, 0.23776313]])

# %%
newdf2
# Out:
#             a         b         c         d         e
# 0    0.249975  0.944033  0.304475  0.348101  0.326889
# 1    0.747093  0.591496  0.077207  0.909630  0.243332
# 2    0.274452  0.365391  0.832035  0.961231  0.075176
# 3    0.926896  0.285163  0.494153  0.965522  0.280765
# 4    0.039616  0.740022  0.198664  0.578210  0.017244
# ..        ...       ...       ...       ...       ...
# 329  0.687377  0.056478  0.245931  0.193304  0.504506
# 330  0.656210  0.328748  0.782255  0.848526  0.808856
# 331  0.549618  0.765701  0.869269  0.483546  0.038572
# 332  0.908573  0.212578  0.105168  0.373238  0.355069
# 333  0.046489  0.638723  0.854807  0.577251  0.237763
#
# [334 rows x 5 columns]

# %%
nf=newdf2.drop(0)

# %%
nf
# Out:
#             a         b         c         d         e
# 1    0.747093  0.591496  0.077207  0.909630  0.243332
# 2    0.274452  0.365391  0.832035  0.961231  0.075176
# 3    0.926896  0.285163  0.494153  0.965522  0.280765
# 4    0.039616  0.740022  0.198664  0.578210  0.017244
# 5    0.788482  0.044743  0.762381  0.792836  0.433401
# ..        ...       ...       ...       ...       ...
# 329  0.687377  0.056478  0.245931  0.193304  0.504506
# 330  0.656210  0.328748  0.782255  0.848526  0.808856
# 331  0.549618  0.765701  0.869269  0.483546  0.038572
# 332  0.908573  0.212578  0.105168  0.373238  0.355069
# 333  0.046489  0.638723  0.854807  0.577251  0.237763
#
# [333 rows x 5 columns]

# %%
nf.reset_index(drop=True)
# Out:
#             a         b         c         d         e
# 0    0.747093  0.591496  0.077207  0.909630  0.243332
# 1    0.274452  0.365391  0.832035  0.961231  0.075176
# 2    0.926896  0.285163  0.494153  0.965522  0.280765
# 3    0.039616  0.740022  0.198664  0.578210  0.017244
# 4    0.788482  0.044743  0.762381  0.792836  0.433401
# ..        ...       ...       ...       ...       ...
# 328  0.687377  0.056478  0.245931  0.193304  0.504506
# 329  0.656210  0.328748  0.782255  0.848526  0.808856
# 330  0.549618  0.765701  0.869269  0.483546  0.038572
# 331  0.908573  0.212578  0.105168  0.373238  0.355069
# 332  0.046489  0.638723  0.854807  0.577251  0.237763
#
# [333 rows x 5 columns]

# %%
import numpy as np,pandas as pd

# %%
df=pd.read_csv("employee.csv")

# %%
df
# Out:
#       1.1,39343.00
# 0     1.3,46205.00
# 1     1.5,37731.00
# 2     2.0,43525.00
# 3     2.2,39891.00
# 4     2.9,56642.00
# 5     3.0,60150.00
# 6     3.2,54445.00
# 7     3.2,64445.00
# 8     3.7,57189.00
# 9     3.9,63218.00
# 10    4.0,55794.00
# 11    4.0,56957.00
# 12    4.1,57081.00
# 13    4.5,61111.00
# 14    4.9,67938.00
# 15    5.1,66029.00
# 16    5.3,83088.00
# 17    5.9,81363.00
# 18    6.0,93940.00
# 19    6.8,91738.00
# 20    7.1,98273.00
# 21   7.9,101302.00
# 22   8.2,113812.00
# 23   8.7,109431.00
# 24   9.0,105582.00
# 25   9.5,116969.00
# 26   9.6,112635.00
# 27  10.3,122391.00
# 28  10.5,121872.00

# %%
df.columns=list("a")

# %%
df
# Out:
#                  a
# 0     1.3,46205.00
# 1     1.5,37731.00
# 2     2.0,43525.00
# 3     2.2,39891.00
# 4     2.9,56642.00
# 5     3.0,60150.00
# 6     3.2,54445.00
# 7     3.2,64445.00
# 8     3.7,57189.00
# 9     3.9,63218.00
# 10    4.0,55794.00
# 11    4.0,56957.00
# 12    4.1,57081.00
# 13    4.5,61111.00
# 14    4.9,67938.00
# 15    5.1,66029.00
# 16    5.3,83088.00
# 17    5.9,81363.00
# 18    6.0,93940.00
# 19    6.8,91738.00
# 20    7.1,98273.00
# 21   7.9,101302.00
# 22   8.2,113812.00
# 23   8.7,109431.00
# 24   9.0,105582.00
# 25   9.5,116969.00
# 26   9.6,112635.00
# 27  10.3,122391.00
# 28  10.5,121872.00

# %%
df["a"].str.split(",",expand=True)
# Out:
#        0          1
# 0    1.3   46205.00
# 1    1.5   37731.00
# 2    2.0   43525.00
# 3    2.2   39891.00
# 4    2.9   56642.00
# 5    3.0   60150.00
# 6    3.2   54445.00
# 7    3.2   64445.00
# 8    3.7   57189.00
# 9    3.9   63218.00
# 10   4.0   55794.00
# 11   4.0   56957.00
# 12   4.1   57081.00
# 13   4.5   61111.00
# 14   4.9   67938.00
# 15   5.1   66029.00
# 16   5.3   83088.00
# 17   5.9   81363.00
# 18   6.0   93940.00
# 19   6.8   91738.00
# 20   7.1   98273.00
# 21   7.9  101302.00
# 22   8.2  113812.00
# 23   8.7  109431.00
# 24   9.0  105582.00
# 25   9.5  116969.00
# 26   9.6  112635.00
# 27  10.3  122391.00
# 28  10.5  121872.00

# %%
df.columns=list(["years experience","salary"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 df.columns=list(["years experience","salary"])
#
# File C:\Python39\lib\site-packages\pandas\core\generic.py:5588, in NDFrame.__setattr__(self, name, value)
#    5586 try:
#    5587     object.__getattribute__(self, name)
# -> 5588     return object.__setattr__(self, name, value)
#    5589 except AttributeError:
#    5590     pass
#
# File C:\Python39\lib\site-packages\pandas\_libs\properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File C:\Python39\lib\site-packages\pandas\core\generic.py:769, in NDFrame._set_axis(self, axis, labels)
#     767 def _set_axis(self, axis: int, labels: Index) -> None:
#     768     labels = ensure_index(labels)
# --> 769     self._mgr.set_axis(axis, labels)
#     770     self._clear_item_cache()
#
# ...

# %%
df.columns=list["years experience","salary"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 df.columns=list["years experience","salary"]
#
# File C:\Python39\lib\site-packages\pandas\core\generic.py:5588, in NDFrame.__setattr__(self, name, value)
#    5586 try:
#    5587     object.__getattribute__(self, name)
# -> 5588     return object.__setattr__(self, name, value)
#    5589 except AttributeError:
#    5590     pass
#
# File C:\Python39\lib\site-packages\pandas\_libs\properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File C:\Python39\lib\site-packages\pandas\core\generic.py:768, in NDFrame._set_axis(self, axis, labels)
#     767 def _set_axis(self, axis: int, labels: Index) -> None:
# --> 768     labels = ensure_index(labels)
#     769     self._mgr.set_axis(axis, labels)
#     770     self._clear_item_cache()
#
# ...

# %%
df.columns=list(["yearsexperience salary"])

# %%
df
# Out:
#    yearsexperience salary
# 0            1.3,46205.00
# 1            1.5,37731.00
# 2            2.0,43525.00
# 3            2.2,39891.00
# 4            2.9,56642.00
# 5            3.0,60150.00
# 6            3.2,54445.00
# 7            3.2,64445.00
# 8            3.7,57189.00
# 9            3.9,63218.00
# 10           4.0,55794.00
# 11           4.0,56957.00
# 12           4.1,57081.00
# 13           4.5,61111.00
# 14           4.9,67938.00
# 15           5.1,66029.00
# 16           5.3,83088.00
# 17           5.9,81363.00
# 18           6.0,93940.00
# 19           6.8,91738.00
# 20           7.1,98273.00
# 21          7.9,101302.00
# 22          8.2,113812.00
# 23          8.7,109431.00
# 24          9.0,105582.00
# 25          9.5,116969.00
# 26          9.6,112635.00
# 27         10.3,122391.00
# 28         10.5,121872.00

# %%
df.columns=list("a")

# %%
df
# Out:
#                  a
# 0     1.3,46205.00
# 1     1.5,37731.00
# 2     2.0,43525.00
# 3     2.2,39891.00
# 4     2.9,56642.00
# 5     3.0,60150.00
# 6     3.2,54445.00
# 7     3.2,64445.00
# 8     3.7,57189.00
# 9     3.9,63218.00
# 10    4.0,55794.00
# 11    4.0,56957.00
# 12    4.1,57081.00
# 13    4.5,61111.00
# 14    4.9,67938.00
# 15    5.1,66029.00
# 16    5.3,83088.00
# 17    5.9,81363.00
# 18    6.0,93940.00
# 19    6.8,91738.00
# 20    7.1,98273.00
# 21   7.9,101302.00
# 22   8.2,113812.00
# 23   8.7,109431.00
# 24   9.0,105582.00
# 25   9.5,116969.00
# 26   9.6,112635.00
# 27  10.3,122391.00
# 28  10.5,121872.00

# %%
df['a'].str.split(",",expand=True)
# Out:
#        0          1
# 0    1.3   46205.00
# 1    1.5   37731.00
# 2    2.0   43525.00
# 3    2.2   39891.00
# 4    2.9   56642.00
# 5    3.0   60150.00
# 6    3.2   54445.00
# 7    3.2   64445.00
# 8    3.7   57189.00
# 9    3.9   63218.00
# 10   4.0   55794.00
# 11   4.0   56957.00
# 12   4.1   57081.00
# 13   4.5   61111.00
# 14   4.9   67938.00
# 15   5.1   66029.00
# 16   5.3   83088.00
# 17   5.9   81363.00
# 18   6.0   93940.00
# 19   6.8   91738.00
# 20   7.1   98273.00
# 21   7.9  101302.00
# 22   8.2  113812.00
# 23   8.7  109431.00
# 24   9.0  105582.00
# 25   9.5  116969.00
# 26   9.6  112635.00
# 27  10.3  122391.00
# 28  10.5  121872.00

# %%
df.rename(columns={0:"experience",1:"salary"},inplace=True)

# %%
df
# Out:
#                  a
# 0     1.3,46205.00
# 1     1.5,37731.00
# 2     2.0,43525.00
# 3     2.2,39891.00
# 4     2.9,56642.00
# 5     3.0,60150.00
# 6     3.2,54445.00
# 7     3.2,64445.00
# 8     3.7,57189.00
# 9     3.9,63218.00
# 10    4.0,55794.00
# 11    4.0,56957.00
# 12    4.1,57081.00
# 13    4.5,61111.00
# 14    4.9,67938.00
# 15    5.1,66029.00
# 16    5.3,83088.00
# 17    5.9,81363.00
# 18    6.0,93940.00
# 19    6.8,91738.00
# 20    7.1,98273.00
# 21   7.9,101302.00
# 22   8.2,113812.00
# 23   8.7,109431.00
# 24   9.0,105582.00
# 25   9.5,116969.00
# 26   9.6,112635.00
# 27  10.3,122391.00
# 28  10.5,121872.00

# %%
newdf=df.rename(columns={"0":"experience","1":"salary"},inplace=True)

# %%
newdf

# %%
newdf

# %%
newdf.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 newdf.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
newdf=df.rename(columns={0:"experience",1:"salary"},inplace=True)

# %%
newdf

# %%
newdf

# %%
df
# Out:
#                  a
# 0     1.3,46205.00
# 1     1.5,37731.00
# 2     2.0,43525.00
# 3     2.2,39891.00
# 4     2.9,56642.00
# 5     3.0,60150.00
# 6     3.2,54445.00
# 7     3.2,64445.00
# 8     3.7,57189.00
# 9     3.9,63218.00
# 10    4.0,55794.00
# 11    4.0,56957.00
# 12    4.1,57081.00
# 13    4.5,61111.00
# 14    4.9,67938.00
# 15    5.1,66029.00
# 16    5.3,83088.00
# 17    5.9,81363.00
# 18    6.0,93940.00
# 19    6.8,91738.00
# 20    7.1,98273.00
# 21   7.9,101302.00
# 22   8.2,113812.00
# 23   8.7,109431.00
# 24   9.0,105582.00
# 25   9.5,116969.00
# 26   9.6,112635.00
# 27  10.3,122391.00
# 28  10.5,121872.00

# %%
newdf =df['a'].str.split(",",expand=True)

# %%
newdf
# Out:
#        0          1
# 0    1.3   46205.00
# 1    1.5   37731.00
# 2    2.0   43525.00
# 3    2.2   39891.00
# 4    2.9   56642.00
# 5    3.0   60150.00
# 6    3.2   54445.00
# 7    3.2   64445.00
# 8    3.7   57189.00
# 9    3.9   63218.00
# 10   4.0   55794.00
# 11   4.0   56957.00
# 12   4.1   57081.00
# 13   4.5   61111.00
# 14   4.9   67938.00
# 15   5.1   66029.00
# 16   5.3   83088.00
# 17   5.9   81363.00
# 18   6.0   93940.00
# 19   6.8   91738.00
# 20   7.1   98273.00
# 21   7.9  101302.00
# 22   8.2  113812.00
# 23   8.7  109431.00
# 24   9.0  105582.00
# 25   9.5  116969.00
# 26   9.6  112635.00
# 27  10.3  122391.00
# 28  10.5  121872.00

# %%
newdf
# Out:
#        0          1
# 0    1.3   46205.00
# 1    1.5   37731.00
# 2    2.0   43525.00
# 3    2.2   39891.00
# 4    2.9   56642.00
# 5    3.0   60150.00
# 6    3.2   54445.00
# 7    3.2   64445.00
# 8    3.7   57189.00
# 9    3.9   63218.00
# 10   4.0   55794.00
# 11   4.0   56957.00
# 12   4.1   57081.00
# 13   4.5   61111.00
# 14   4.9   67938.00
# 15   5.1   66029.00
# 16   5.3   83088.00
# 17   5.9   81363.00
# 18   6.0   93940.00
# 19   6.8   91738.00
# 20   7.1   98273.00
# 21   7.9  101302.00
# 22   8.2  113812.00
# 23   8.7  109431.00
# 24   9.0  105582.00
# 25   9.5  116969.00
# 26   9.6  112635.00
# 27  10.3  122391.00
# 28  10.5  121872.00

# %%
ndf=newdf.rename(columns=list("years"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 ndf=newdf.rename(columns=list("years"))
#
# File C:\Python39\lib\site-packages\pandas\core\frame.py:5083, in DataFrame.rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    4964 def rename(
#    4965     self,
#    4966     mapper: Renamer | None = None,
#    (...)
#    4974     errors: str = "ignore",
#    4975 ) -> DataFrame | None:
#    4976     """
#    4977     Alter axes labels.
#    4978
#    (...)
#    5081     4  3  6
#    5082     """
# -> 5083     return super()._rename(
#    5084         mapper=mapper,
#    5085         index=index,
#    5086         columns=columns,
#    5087         axis=axis,
#    5088         copy=copy,
#    5089         inplace=inplace,
#    5090         level=level,
#    5091         errors=errors,
#    5092     )
#
# ...

# %%
ndf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 ndf
#
# NameError: name 'ndf' is not defined

# %%
newdf
# Out:
#        0          1
# 0    1.3   46205.00
# 1    1.5   37731.00
# 2    2.0   43525.00
# 3    2.2   39891.00
# 4    2.9   56642.00
# 5    3.0   60150.00
# 6    3.2   54445.00
# 7    3.2   64445.00
# 8    3.7   57189.00
# 9    3.9   63218.00
# 10   4.0   55794.00
# 11   4.0   56957.00
# 12   4.1   57081.00
# 13   4.5   61111.00
# 14   4.9   67938.00
# 15   5.1   66029.00
# 16   5.3   83088.00
# 17   5.9   81363.00
# 18   6.0   93940.00
# 19   6.8   91738.00
# 20   7.1   98273.00
# 21   7.9  101302.00
# 22   8.2  113812.00
# 23   8.7  109431.00
# 24   9.0  105582.00
# 25   9.5  116969.00
# 26   9.6  112635.00
# 27  10.3  122391.00
# 28  10.5  121872.00

# %%
ndf=newdf.rename(columns = {'0':'yearsexperience', '1':'salary'}, inplace = True)

# %%
ndf

# %%
newdf
# Out:
#        0          1
# 0    1.3   46205.00
# 1    1.5   37731.00
# 2    2.0   43525.00
# 3    2.2   39891.00
# 4    2.9   56642.00
# 5    3.0   60150.00
# 6    3.2   54445.00
# 7    3.2   64445.00
# 8    3.7   57189.00
# 9    3.9   63218.00
# 10   4.0   55794.00
# 11   4.0   56957.00
# 12   4.1   57081.00
# 13   4.5   61111.00
# 14   4.9   67938.00
# 15   5.1   66029.00
# 16   5.3   83088.00
# 17   5.9   81363.00
# 18   6.0   93940.00
# 19   6.8   91738.00
# 20   7.1   98273.00
# 21   7.9  101302.00
# 22   8.2  113812.00
# 23   8.7  109431.00
# 24   9.0  105582.00
# 25   9.5  116969.00
# 26   9.6  112635.00
# 27  10.3  122391.00
# 28  10.5  121872.00

# %%
ndf=newdf.rename(columns = {0:'yearsexperience', 1:'salary'}, inplace = True)

# %%
newdf.columns=list("ab")

# %%
newdf.to_csv("hello.csv")

# %%
ndf=read_csv("hello.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 ndf=read_csv("hello.csv")
#
# NameError: name 'read_csv' is not defined

# %%
ndf=pd.read_csv("hello.csv")

# %%
ndf
# Out:
#     Unnamed: 0     a         b
# 0            0   1.3   46205.0
# 1            1   1.5   37731.0
# 2            2   2.0   43525.0
# 3            3   2.2   39891.0
# 4            4   2.9   56642.0
# 5            5   3.0   60150.0
# 6            6   3.2   54445.0
# 7            7   3.2   64445.0
# 8            8   3.7   57189.0
# 9            9   3.9   63218.0
# 10          10   4.0   55794.0
# 11          11   4.0   56957.0
# 12          12   4.1   57081.0
# 13          13   4.5   61111.0
# 14          14   4.9   67938.0
# 15          15   5.1   66029.0
# 16          16   5.3   83088.0
# 17          17   5.9   81363.0
# 18          18   6.0   93940.0
# 19          19   6.8   91738.0
# 20          20   7.1   98273.0
# 21          21   7.9  101302.0
# 22          22   8.2  113812.0
# 23          23   8.7  109431.0
# 24          24   9.0  105582.0
# 25          25   9.5  116969.0
# 26          26   9.6  112635.0
# 27          27  10.3  122391.0
# 28          28  10.5  121872.0

# %%
ndf.head(3)
# Out:
#    Unnamed: 0    a        b
# 0           0  1.3  46205.0
# 1           1  1.5  37731.0
# 2           2  2.0  43525.0

# %%
ndf.drop(0,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 ndf.drop(0,axis=1)
#
# File C:\Python39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\Python39\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
# ...

# %%
ndf.drop(["Unnamed:0"],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [53], in <cell line: 1>()
# ----> 1 ndf.drop(["Unnamed:0"],axis=1,inplace=True)
#
# File C:\Python39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\Python39\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...

# %%
ndf.head(4)
# Out:
#    Unnamed: 0    a        b
# 0           0  1.3  46205.0
# 1           1  1.5  37731.0
# 2           2  2.0  43525.0
# 3           3  2.2  39891.0

# %%
ndf=pd.read_csv(df.to_csv("hello.csv"), index_col=[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 ndf=pd.read_csv(df.to_csv("hello.csv"), index_col=[0])
#
# File C:\Python39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
ndf
# Out:
#     Unnamed: 0     a         b
# 0            0   1.3   46205.0
# 1            1   1.5   37731.0
# 2            2   2.0   43525.0
# 3            3   2.2   39891.0
# 4            4   2.9   56642.0
# 5            5   3.0   60150.0
# 6            6   3.2   54445.0
# 7            7   3.2   64445.0
# 8            8   3.7   57189.0
# 9            9   3.9   63218.0
# 10          10   4.0   55794.0
# 11          11   4.0   56957.0
# 12          12   4.1   57081.0
# 13          13   4.5   61111.0
# 14          14   4.9   67938.0
# 15          15   5.1   66029.0
# 16          16   5.3   83088.0
# 17          17   5.9   81363.0
# 18          18   6.0   93940.0
# 19          19   6.8   91738.0
# 20          20   7.1   98273.0
# 21          21   7.9  101302.0
# 22          22   8.2  113812.0
# 23          23   8.7  109431.0
# 24          24   9.0  105582.0
# 25          25   9.5  116969.0
# 26          26   9.6  112635.0
# 27          27  10.3  122391.0
# 28          28  10.5  121872.0

# %%
newdf=pd.to_csv(ndf,index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 newdf=pd.to_csv(ndf,index=False)
#
# File C:\Python39\lib\site-packages\pandas\__init__.py:261, in __getattr__(name)
#     257     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     259     return _SparseArray
# --> 261 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'to_csv'

# %%
ndf
# Out:
#     Unnamed: 0     a         b
# 0            0   1.3   46205.0
# 1            1   1.5   37731.0
# 2            2   2.0   43525.0
# 3            3   2.2   39891.0
# 4            4   2.9   56642.0
# 5            5   3.0   60150.0
# 6            6   3.2   54445.0
# 7            7   3.2   64445.0
# 8            8   3.7   57189.0
# 9            9   3.9   63218.0
# 10          10   4.0   55794.0
# 11          11   4.0   56957.0
# 12          12   4.1   57081.0
# 13          13   4.5   61111.0
# 14          14   4.9   67938.0
# 15          15   5.1   66029.0
# 16          16   5.3   83088.0
# 17          17   5.9   81363.0
# 18          18   6.0   93940.0
# 19          19   6.8   91738.0
# 20          20   7.1   98273.0
# 21          21   7.9  101302.0
# 22          22   8.2  113812.0
# 23          23   8.7  109431.0
# 24          24   9.0  105582.0
# 25          25   9.5  116969.0
# 26          26   9.6  112635.0
# 27          27  10.3  122391.0
# 28          28  10.5  121872.0

# %%
ndf.drop(ndf.filter(regex="Unname"),axis=1, inplace=True)

# %%
ndf
# Out:
#        a         b
# 0    1.3   46205.0
# 1    1.5   37731.0
# 2    2.0   43525.0
# 3    2.2   39891.0
# 4    2.9   56642.0
# 5    3.0   60150.0
# 6    3.2   54445.0
# 7    3.2   64445.0
# 8    3.7   57189.0
# 9    3.9   63218.0
# 10   4.0   55794.0
# 11   4.0   56957.0
# 12   4.1   57081.0
# 13   4.5   61111.0
# 14   4.9   67938.0
# 15   5.1   66029.0
# 16   5.3   83088.0
# 17   5.9   81363.0
# 18   6.0   93940.0
# 19   6.8   91738.0
# 20   7.1   98273.0
# 21   7.9  101302.0
# 22   8.2  113812.0
# 23   8.7  109431.0
# 24   9.0  105582.0
# 25   9.5  116969.0
# 26   9.6  112635.0
# 27  10.3  122391.0
# 28  10.5  121872.0

# %%
ndf.to_csv("hello.csv")

# %%
ndf
# Out:
#        a         b
# 0    1.3   46205.0
# 1    1.5   37731.0
# 2    2.0   43525.0
# 3    2.2   39891.0
# 4    2.9   56642.0
# 5    3.0   60150.0
# 6    3.2   54445.0
# 7    3.2   64445.0
# 8    3.7   57189.0
# 9    3.9   63218.0
# 10   4.0   55794.0
# 11   4.0   56957.0
# 12   4.1   57081.0
# 13   4.5   61111.0
# 14   4.9   67938.0
# 15   5.1   66029.0
# 16   5.3   83088.0
# 17   5.9   81363.0
# 18   6.0   93940.0
# 19   6.8   91738.0
# 20   7.1   98273.0
# 21   7.9  101302.0
# 22   8.2  113812.0
# 23   8.7  109431.0
# 24   9.0  105582.0
# 25   9.5  116969.0
# 26   9.6  112635.0
# 27  10.3  122391.0
# 28  10.5  121872.0

# %%
df.loc[-1]=[1.1,39343]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [66], in <cell line: 1>()
# ----> 1 df.loc[-1]=[1.1,39343]
#
# File C:\Python39\lib\site-packages\pandas\core\indexing.py:716, in _LocationIndexer.__setitem__(self, key, value)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File C:\Python39\lib\site-packages\pandas\core\indexing.py:1682, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1679     indexer, missing = convert_missing_indexer(indexer)
#    1681     if missing:
# -> 1682         self._setitem_with_indexer_missing(indexer, value)
#    1683         return
#    1685 # align and set the values
#
# ...

# %%
import pandas as pd
dataset = pd.read_csv('hello.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:,1].values

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
X
# Out:
# array([[ 0. ,  1.1],
#        [ 1. ,  1.3],
#        [ 2. ,  1.5],
#        [ 3. ,  2. ],
#        [ 4. ,  2.2],
#        [ 5. ,  2.9],
#        [ 6. ,  3. ],
#        [ 7. ,  3.2],
#        [ 8. ,  3.2],
#        [ 9. ,  3.7],
#        [10. ,  3.9],
#        [11. ,  4. ],
#        [12. ,  4. ],
#        [13. ,  4.1],
#        [14. ,  4.5],
#        [15. ,  4.9],
#        [16. ,  5.1],
#        [17. ,  5.3],
#        [18. ,  5.9],
#        [19. ,  6. ],
#        [20. ,  6.8],
#        [21. ,  7.1],
#        [22. ,  7.9],
#        [23. ,  8.2],
#        [24. ,  8.7],
#        [25. ,  9. ],
#        [26. ,  9.5],
#        [27. ,  9.6],
#        [28. , 10.3],
#        [29. , 10.5]])

# %%
dataset
# Out:
#     Unnamed: 0   exp    salary
# 0            0   1.1   39343.0
# 1            1   1.3   46205.0
# 2            2   1.5   37731.0
# 3            3   2.0   43525.0
# 4            4   2.2   39891.0
# 5            5   2.9   56642.0
# 6            6   3.0   60150.0
# 7            7   3.2   54445.0
# 8            8   3.2   64445.0
# 9            9   3.7   57189.0
# 10          10   3.9   63218.0
# 11          11   4.0   55794.0
# 12          12   4.0   56957.0
# 13          13   4.1   57081.0
# 14          14   4.5   61111.0
# 15          15   4.9   67938.0
# 16          16   5.1   66029.0
# 17          17   5.3   83088.0
# 18          18   5.9   81363.0
# 19          19   6.0   93940.0
# 20          20   6.8   91738.0
# 21          21   7.1   98273.0
# 22          22   7.9  101302.0
# 23          23   8.2  113812.0
# 24          24   8.7  109431.0
# 25          25   9.0  105582.0
# 26          26   9.5  116969.0
# 27          27   9.6  112635.0
# 28          28  10.3  122391.0
# ...

# %%
import pandas as pd
dataset = pd.read_csv('hello.csv',index=0)
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:,1].values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 dataset = pd.read_csv('hello.csv',index=0)
#       3 X = dataset.iloc[:, :-1].values
#       4 y = dataset.iloc[:,1].values
#
# File C:\Python39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %%
mport pandas as pd
dataset = pd.read_csv('hello.csv',index[0])
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:,1].values
# Out:
#   Input In [6]
#     mport pandas as pd
#           ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
dataset = pd.read_csv('hello.csv',index[0])
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:,1].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 dataset = pd.read_csv('hello.csv',index[0])
#       3 X = dataset.iloc[:, :-1].values
#       4 y = dataset.iloc[:,1].values
#
# NameError: name 'index' is not defined

# %%
import pandas as pd
dataset = pd.read_csv('hello.csv',index([0]))
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:,1].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 dataset = pd.read_csv('hello.csv',index([0]))
#       3 X = dataset.iloc[:, :-1].values
#       4 y = dataset.iloc[:,1].values
#
# NameError: name 'index' is not defined

# %%
import pandas as pd
dataset = pd.read_csv('hello.csv',index(0))
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:,1].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 dataset = pd.read_csv('hello.csv',index(0))
#       3 X = dataset.iloc[:, :-1].values
#       4 y = dataset.iloc[:,1].values
#
# NameError: name 'index' is not defined

# %%
import pandas as pd
dataset = pd.read_csv('hello.csv')
del dataset["Unnamed: 0"]
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:,1].values

# %%
dataset
# Out:
#      exp    salary
# 0    1.1   39343.0
# 1    1.3   46205.0
# 2    1.5   37731.0
# 3    2.0   43525.0
# 4    2.2   39891.0
# 5    2.9   56642.0
# 6    3.0   60150.0
# 7    3.2   54445.0
# 8    3.2   64445.0
# 9    3.7   57189.0
# 10   3.9   63218.0
# 11   4.0   55794.0
# 12   4.0   56957.0
# 13   4.1   57081.0
# 14   4.5   61111.0
# 15   4.9   67938.0
# 16   5.1   66029.0
# 17   5.3   83088.0
# 18   5.9   81363.0
# 19   6.0   93940.0
# 20   6.8   91738.0
# 21   7.1   98273.0
# 22   7.9  101302.0
# 23   8.2  113812.0
# 24   8.7  109431.0
# 25   9.0  105582.0
# 26   9.5  116969.0
# 27   9.6  112635.0
# 28  10.3  122391.0
# 29  10.5  121872.0

# %%
X
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 from sklearn.model_selection import train_test_split
#       2 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 from sklearn.model_selection import train_test_split
#       2 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
sklearn
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 sklearn
#
# NameError: name 'sklearn' is not defined

# %%
import sklearn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 import sklearn
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import Sklearn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 import Sklearn
#
# ModuleNotFoundError: No module named 'Sklearn'

# %%
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import sklearn.model_selection
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 import sklearn.model_selection
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)
#
# NameError: name 'X' is not defined

# %%
dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 dataset
#
# NameError: name 'dataset' is not defined

# %%
import pandas as pd
dataset = pd.read_csv('hello.csv')
del dataset("unnamed: 0")
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:,1].values
# Out:
#   Input In [4]
#     del dataset("unnamed: 0")
#         ^
# SyntaxError: cannot delete function call

# %%
import pandas as pd
dataset = pd.read_csv('hello.csv')
del dataset["unnamed: 0"]
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:,1].values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Python39\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\Python39\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Python39\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'unnamed: 0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import pandas as pd
dataset = pd.read_csv('hello.csv')
del dataset("Unnamed: 0")
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:,1].values
# Out:
#   Input In [6]
#     del dataset("Unnamed: 0")
#         ^
# SyntaxError: cannot delete function call

# %%
import pandas as pd
dataset = pd.read_csv('hello.csv')
del dataset["Unnamed: 0"]
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:,1].values

# %%
X
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([ 40835.10590871, 123079.39940819,  65134.55626083,  63265.36777221,
#        115602.64545369, 108125.8914992 , 116537.23969801,  64199.96201652,
#         76349.68719258, 100649.1375447 ])

# %%
y_test
# Out:
# array([ 37731., 122391.,  57081.,  63218., 116969., 109431., 112635.,
#         55794.,  83088., 101302.])

# %%
plt.scatter(X_train, y_train, color = ‘red’)
# Out:
#   Input In [16]
#     plt.scatter(X_train, y_train, color = ‘red’)
#                                           ^
# SyntaxError: invalid character '‘' (U+2018)

# %%
plt.scatter(X_train, y_train, color = 'red')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 plt.scatter(X_train, y_train, color = 'red')
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as pp
pp.scatter(X_train,y_train,color='red')

# %%
pp.scatter(X_test,y_test,color='blue')

# %%
pp.scatter(X_test,y_test,color='red')
pp.plot(X_train, regressor.predict(X_train), color='blue')
pp.title('Salary vs Experience (Test set)')
pp.xlabel('experience')
pp.ylabel('salary')
pp.show()

# %%
pp.xlabel("experience")
# Out:
# Text(0.5, 0, 'experience')

# %%
pp.scatter(X_test,y_test,color='red')
pp.plot(X_train, regressor.predict(X_train), color='blue')
pp.title('Salary vs Experience (Test set)')
pp.xlabel('experience')
pp.ylabel('salary')
pp.show()

# %%
newPred=regressor.predict([[15]])

# %%
print('The predicted salary of a person with 15 years experience is ',newPred)
# Out:
# The predicted salary of a person with 15 years experience is  [167005.32889087]
